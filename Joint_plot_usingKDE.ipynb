# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('character-deaths.csv')
sns.jointplot(x='Book of Death',y='Book Intro Chapter',data=df,kind='kde')
plt.xlabel('Book of Death')
plt.ylabel('Book Intro Chapter')
plt.show()
